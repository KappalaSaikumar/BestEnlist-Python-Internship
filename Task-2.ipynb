# %% [markdown]
# # Task 2 : Variables & Data types

# %%
# Integer assignment
number_of_wheels=2
print(number_of_wheels)
# Out:
# 2

# %%
# Floating point numbers
pie=3.14
print(pie)
# Out:
# 3.14

# %%
# String assignment
Player="Virat Kohli"
print(Player)
# Out:
# Virat Kohli

# %%
# Assigning same value to several variables
a=b=c=1
print(a,b,c)
# Out:
# 1 1 1

# %%
# Assigning multiple objects to multiple variables
a,b,c=1,18,"Kohli"
print(a,b,c)
# Out:
# 1 18 Kohli

# %%
# Exercise 1
a=b=c=1
a=a/10
b=b/50
c=c+50
print(a,b,c)
# Out:
# 0.1 0.02 51

# %%
# Exercise 2
val="Index"
list_val=list(val)
list_val[2]="G"
result="".join(list_val)
print(result)
# Out:
# InGex

# %%
# Exercise 3
a=1
b=3.56
a=float(a)
b=int(b)
print(a,"= a",";",b,"= b")
# Out:
# 1.0 = a ; 3 = b
