# %% [markdown]
# # Task-11

# %%
# Exercise-1

a=(1,2,3)
b=(2,3,4)
c=(1,2,2,3,4,5)
print(list(zip(a,b,c)))
# Out:
# [(1, 2, 1), (2, 3, 2), (3, 4, 2)]

# %%
# Exercise-2

def func2(list1):
    list2=list(range(1,9))
    return list(zip(list2,list1))

# %%
print(func2([34,16,36,15,90,22,17,89]))
# Out:
# [(1, 34), (2, 16), (3, 36), (4, 15), (5, 90), (6, 22), (7, 17), (8, 89)]

# %%
# Exercise-3

def func3(list3):
    list3.sort()
    return list3

# %%
print(func3(['Ford', 'BMW', 'Volvo']))
# Out:
# ['BMW', 'Ford', 'Volvo']

# %%
print(func3([23,1,43,463,67,4,76,2]))
# Out:
# [1, 2, 4, 23, 43, 67, 76, 463]

# %%
#Exercise-4

def odd(num):
    if num%2==0:
        return False
    else:
        return True
    
def filterer(list5):
    return list(filter(odd,list5))

# %%
print(filterer([1,34,231,2423,24,12,46,23,5765]))
# Out:
# [1, 231, 2423, 23, 5765]
