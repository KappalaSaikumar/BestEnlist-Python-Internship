# %% [markdown]
# # Task-12 Python JSON

# %%
import json 

var={
    "name":"Saikumar",
    "age":19,
    "married":False,
    "Student":True,
    "FavCricketers":("Virat","Bumrah","Abd"),
    "pets":None,
    "Skills":[{"Programming":"Java,Python"},
             {"Others":"Machine learning"}]
}

JSON=json.dumps(var)
print(JSON)
# Out:
# {"name": "Saikumar", "age": 19, "married": false, "Student": true, "FavCricketers": ["Virat", "Bumrah", "Abd"], "pets": null, "Skills": [{"Programming": "Java,Python"}, {"Others": "Machine learning"}]}

# %%
print(json.dumps(var,indent=4))
# Out:
# {
#     "name": "Saikumar",
#     "age": 19,
#     "married": false,
#     "Student": true,
#     "FavCricketers": [
#         "Virat",
#         "Bumrah",
#         "Abd"
#     ],
#     "pets": null,
#     "Skills": [
#         {
#             "Programming": "Java,Python"
#         },
#         {
#             "Others": "Machine learning"
#         }
#     ]
# }

# %%
print(json.dumps(var,indent=4,separators=(". ","= "),sort_keys=True))
# Out:
# {
#     "FavCricketers"= [
#         "Virat".
#         "Bumrah".
#         "Abd"
#     ].
#     "Skills"= [
#         {
#             "Programming"= "Java,Python"
#         }.
#         {
#             "Others"= "Machine learning"
#         }
#     ].
#     "Student"= true.
#     "age"= 19.
#     "married"= false.
#     "name"= "Saikumar".
#     "pets"= null
# }
