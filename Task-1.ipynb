# %% [markdown]
# # BestEnlist Python Internship

# %% [markdown]
# **Task-1**

# %%
# 1- Indexing using python
Days="Thirty days"
print(Days[0])
# Out:
# T

# %%
# 2- Printing particular character from certain text
Challenge="I will win"
print(Challenge[7:10])
# Out:
# win

# %%
# 3- Print length of character
print(len(Challenge))
# Out:
# 10

# %%
# 4- Convert String to lowercase
print(Challenge.lower())
# Out:
# i will win

# %%
# 5- String Concatenation
a="30 Days"
b="30 hours"
print(a+" "+b)
# Out:
# 30 Days 30 hours

# %%
# 6- casefold() usage
text="Thirty days and Thirty hours"
x=text.casefold()
print(x)
# Out:
# thirty days and thirty hours

# %%
# Exercise
string="First Task of BestEnlist Python Internship"
print(string[1:])
# Out:
# irst Task of BestEnlist Python Internship
