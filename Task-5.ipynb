# %% [markdown]
# # Task-5 Functions

# %%
# Example
def myFun(num):
    num[0]=20

# %%
list1=[1,2,3,4,5]
myFun(list1)
print(list1)
# Out:
# [20, 2, 3, 4, 5]

# %%
# Example
def my_function(*team):
    print("The youngest member of the team is "+ team[0])

# %%
my_function("sam","tom","ben")
# Out:
# The youngest member of the team is sam

# %%
# Example
def my_function1(**kwargs):
    print("My favourite player is "+ kwargs["fav"])
    return kwargs["fav2"]

# %%
print(my_function1(fav="Kohli",fav2="Bumrah"))
# Out:
# My favourite player is Kohli
# Bumrah

# %%
# Exercise-1

def func(int1,int2):
    print("Addition of two numbers is ",int1+int2)
    print("Subtraction of two numbers is ",int1-int2)
    print("Division of two numbers is ",int1/int2)
    print("Multiplication of two numbers is ",int1*int2)

# %%
func(6,3)
# Out:
# Addition of two numbers is  9
# Subtraction of two numbers is  3
# Division of two numbers is  2.0
# Multiplication of two numbers is  18

# %%
# Exercise-2

def covid(**kwargs):
    try:
        kwargs["temperature"]
    except KeyError:
        temperature=98
        
    name=kwargs["name"]
    
    print(name)
    print(temperature)

# %%
covid(name="Python")
# Out:
# Python
# 98
